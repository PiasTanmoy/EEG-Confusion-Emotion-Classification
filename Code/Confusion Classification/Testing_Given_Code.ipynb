# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import sys
import os
prefix = '/content/gdrive/My Drive/'
# modify "customized_path_to_your_homework" here to where you uploaded your homework
customized_path_to_your_homework = 'Final_Project'
sys_path = os.path.join(prefix, customized_path_to_your_homework)
sys.path.append(sys_path)

# %%
# !pip install numpy
# !pip install sklearn
# !pip install nolearn
# !pip install dbn
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: nolearn in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: Lasagne in /usr/local/lib/python3.7/dist-packages (from nolearn) (0.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from nolearn) (0.8.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nolearn) (1.0.1)
# Requirement already satisfied: Theano in /usr/local/lib/python3.7/dist-packages (from nolearn) (1.0.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from nolearn) (0.22.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from Lasagne->nolearn) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Theano->nolearn) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from Theano->nolearn) (1.15.0)
# Collecting dbn
#   Using cached https://files.pythonhosted.org/packages/b8/5b/a9f142fc4462636ecfc40b59aa321b5ddbe08879d798c83107a6b6c8f9d0/DBN-0.1.0-py3-none-any.whl
# Collecting python-jwt
#   Using cached https://files.pythonhosted.org/packages/91/bb/b25bab0cb862317d0afd34b38fd95f417a5a80fc5313a3f049952626f283/python_jwt-3.3.0-py2.py3-none-any.whl
# Collecting pybluez
#   Using cached https://files.pythonhosted.org/packages/08/9f/e9d93b266d2d1ea988780a52a696073ba0a65df65a532165fdf6ff90d0ed/PyBluez-0.23.tar.gz
# Collecting jwcrypto>=0.8
#   Using cached https://files.pythonhosted.org/packages/cc/a8/2ab318a407025203579bb4f45ec4ab80bff2c5a69c41ab39558bdf3c985d/jwcrypto-0.8-py2.py3-none-any.whl
# Collecting cryptography>=2.3
#   Using cached https://files.pythonhosted.org/packages/b2/26/7af637e6a7e87258b963f1731c5982fb31cd507f0d90d91836e446955d02/cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.3->jwcrypto>=0.8->python-jwt->dbn) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.3->jwcrypto>=0.8->python-jwt->dbn) (2.20)
# Building wheels for collected packages: pybluez
#   Building wheel for pybluez (setup.py) ... error
#   ERROR: Failed building wheel for pybluez
#   Running setup.py clean for pybluez
# Failed to build pybluez
# Installing collected packages: cryptography, jwcrypto, python-jwt, pybluez, dbn
#     Running setup.py install for pybluez ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-ycvmf8gs/pybluez/setup.py'"'"'; __file__='"'"'/tmp/pip-install-ycvmf8gs/pybluez/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-a22q980_/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.

# %%
import csv
import numpy as np
import scipy.io as sio
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.model_selection import cross_val_score
from nolearn.dbn import DBN
from sklearn.metrics import classification_report, accuracy_score
from dbn.tensorflow import SupervisedDBNClassification
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-fb4f4edefb5d> in <module>()
#       6 from sklearn import svm
#       7 from sklearn.model_selection import cross_val_score
# ----> 8 from nolearn.dbn import DBN
#       9 from sklearn.metrics import classification_report, accuracy_score
#      10 from dbn.tensorflow import SupervisedDBNClassification
#
# /usr/local/lib/python3.7/dist-packages/nolearn/dbn.py in <module>()
#       3 import warnings
#       4
# ----> 5 from gdbn.dbn import buildDBN
#       6 from gdbn import activationFunctions
#       7 import numpy as np
#
# ModuleNotFoundError: No module named 'gdbn'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
